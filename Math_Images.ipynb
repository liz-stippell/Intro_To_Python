# %%
x = 0
y = 0

x_list = []
y_list = []

for i in range(0, 100):
    x = -0.8-0.1*x+1.1*x**2-1.2*x*y+0.3*y+1.1*y**2
    y = 0.3*x + 0.4*x**2 + 0.2*x*y - 1.1*y + 0.7*y**2
    
    x = x
    y = y
    x_list.append(x)
    y_list.append(y)
    print(x)
# Out:
# -0.8
# 0.004441600000000297
# -0.8048727568728536
# 0.04292311137265001
# -0.8081653427153743
# 0.07009967136931083
# -0.8075197345224665
# 0.0793710268176565
# -0.807085604963564
# 0.08595563204709224
# -0.8065628686348287
# 0.08980452218051604
# -0.8062161461313185
# 0.09254644471453138
# -0.8059274684714509
# 0.09428620195352531
# -0.8057365471106345
# 0.09552587549638224
# -0.8055907534151927
# 0.09633791312717228
# -0.8054940923191775
# 0.09691519272642361
# -0.8054228341971442
# 0.09729944972346159
# -0.8053753769755964
# 0.09757170376582659
# -0.8053410263113507
# 0.09775464671607018
# -0.8053180334025839
# 0.0978838067019695
# -0.8053015743465611
# 0.09797113972136605
# -0.8052905034003041
# 0.09803259266241668
# -0.805282637751433
# 0.0980743306366788
# -0.8052773236354819
# 0.09810361327568094
# -0.8052735686896005
# 0.0981235688030746
# -0.8052710220503911
# 0.09813753366930406
# -0.8052692301198043
# 0.09814707556931306
# -0.8052680108407819
# 0.09815373865353015
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(x_list, y_list, "o")

# %%
x = 0.0
y = 0.0

x_list = []
y_list = []

for i in range(0, 10000):
    x_prev = x
    y_prev = y
    x = -0.8 - 0.1*x_prev + 1.1*x_prev**2 - 1.2*x_prev*y_prev + 0.3*y_prev + 1.1*y_prev**2
    y = 0.3*x_prev + 0.4*x_prev**2 + 0.2*x_prev*y_prev - 1.1*y_prev + 0.7*y_prev**2
    
    y_list.append(y)
    x_list.append(x)
    
#    print(x)

# %%
plt.scatter(x_list, y_list, s = 1)

# %%
import math

# %%
x = 1
y = 1

b = 0.83
a = 0.67

x_list = []
y_list = []

for i in range(0, 10000):
    x = xnew
    y = ynew
    xnew=math.sin(x*y/b)*y+math.cos(a*x-y)
    ynew=x+math.sin(y)/b
    
    x_list.append(x)
    y_list.append(y)

#print(x_list)

# %%
plt.scatter(x_list, y_list, s=1)

# %%
x_list = []
y_list = []

x = 0.1
y = 0.1

a = 1.7
b = 1.3
c = 0.1
d = 1.21

for i in range(0, 10000):
    x = xnew
    y = ynew
    xnew=math.sin(a*y)+c*math.cos(a*x)
    ynew=math.sin(b*x)+d*math.cos(b*y)
    
    x_list.append(x)
    y_list.append(y)

# %%
plt.scatter(x_list, y_list, s=1)
